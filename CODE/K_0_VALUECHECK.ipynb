# %%
import numpy as np
import getdist
import matplotlib.pyplot as plt
from getdist import plots, MCSamples

# %%
data = np.loadtxt("RESULT_5param40_2000_200/chain.dat")

# %%
k0 = data[:,-1]
logk = np.log10(k0) - np.log10(365)
# Out:
# C:\Users\Gaurav Singh\AppData\Local\Temp\ipykernel_3148\4036669607.py:2: RuntimeWarning: invalid value encountered in log10
#   logk = np.log10(k0) - np.log10(365)

# %%
data
# Out:
# array([[ 4.99072099, 37.87071308,  0.05996592, 40.89908837, -2.94519146],
#        [ 4.99072099, 37.87071308,  0.05996592, 40.89908837, -2.94519146],
#        [ 4.99072099, 37.87071308,  0.05996592, 40.89908837, -2.94519146],
#        ...,
#        [ 5.75794119, 30.99641998,  0.52846918, 42.06839152, -0.95115603],
#        [ 5.75794119, 30.99641998,  0.52846918, 42.06839152, -0.95115603],
#        [ 5.77382609, 30.3849466 ,  0.50727325, 42.09209917, -0.83638397]],
#       shape=(80000, 5))

# %%
# # -------- Step 1: take log10 of last column --------
# data_log = data.copy()

# # Avoid log10 issues (important!)
# # Remove or mask non-positive values
# mask = data_log[:, -1] > 0
# data_log = data_log[mask]

# # Apply log10 transform
# data_log[:, -1] = np.log10(data_log[:, -1])

# # Names
# names = [
#     "log10_R_all_sky",
#     # "log10_E_min_pop",
#     "gamma",
#     "log10_E_star",
#     "alpha", "logk"
# ]

# # FIXED LABELS (NO $ SYMBOL)
# labels = [
#     r"\log_{10} R_{\mathrm{all\ sky}}",
#     # r"\log_{10} E_{\min}",
#     r"\gamma",
#     r"\log_{10} E_\star",
#     r"\alpha", r'log('
# ]

# # -------- Step 3: create MCSamples --------
# samples = MCSamples(samples=data_log, names=names, labels=labels)

# # -------- Step 4: make contour plot --------
# g = plots.get_subplot_plotter()

# g.triangle_plot(samples, filled=True)

# %%
k_pos = logk[logk>=0]

# %%
len(k_pos)
# Out:
# 0

# %%
np.max(logk)
# Out:
# np.float64(nan)
